# %%
# Import libraries
import numpy as np
import random
import cv2
import os
import glob
import matplotlib.pyplot as plt

import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
from keras.preprocessing.image import img_to_array
from keras.utils import to_categorical, plot_model
from keras.models import Sequential
from keras.callbacks import EarlyStopping
from keras.layers import BatchNormalization, Conv2D, MaxPooling2D, Activation, Flatten, Dropout, Dense
from keras import backend as K
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report,ConfusionMatrixDisplay

# %%
# Configurations
batch_size = 64
epochs = 100
img_dims = (96,96,3)
#lr = 1e-3

# %%
# Specify the directory containing image files
directory_path = '/Users/ronja/Desktop/DS22_EC/8_Deep_Learning/Kunskapskontoller_DL/Kunskapskontroll_2/GenderDetection/gender_dataset_face'

# Find all files in the specified directory and its subdirectories
all_files = glob.glob(directory_path + '/**/*', recursive=True)

# Create a list to store file paths (excluding directories)
image_files = [file_path for file_path in all_files if not os.path.isdir(file_path)]

# Shuffle the list of image files randomly
random.shuffle(image_files)

# %%
# Create lists to contain data
data = []
labels = []

# Converting images to arrays and labelling the categories
for img in image_files:
    image = cv2.imread(img)
    image = cv2.resize(image, (96, 96))
    image = img_to_array(image)
    data.append(image)

    label = img.split(os.path.sep)[-2]
    if label == "woman":
        label = 1
    else:
        label = 0
        
    labels.append([label]) # [[1], [0], [0], ...]

# %%
# Convert list to np arrays
data = np.array(data, dtype="float") / 255.0
labels = np.array(labels)

# Check shape of the data
print("Shape of data:", data.shape)  
print("Shape of labels:", labels.shape)
# Out:
# Shape of data: (2307, 96, 96, 3)
# Shape of labels: (2307, 1)

# %%
# Split dataset for training and validation
(X_train, X_test, y_train, y_test) = train_test_split(data, labels, test_size=0.2, random_state=42)

# %%
y_train = to_categorical(y_train, num_classes=2) # [[1, 0], [0, 1], [0, 1], ...]
y_test = to_categorical(y_test, num_classes=2)

# %%
# Augmenting datset 
aug = ImageDataGenerator(rotation_range=25, width_shift_range=0.1,
                         height_shift_range=0.1, shear_range=0.2, zoom_range=0.2,
                         horizontal_flip=True, fill_mode="nearest")

# %%
# Model function - you can create a function to build a model instead of building each model from stratch 
def build_model(width, height, depth, classes):
    model = Sequential()
    inputShape = (height, width, depth)
    chanDim = -1

    if K.image_data_format() == "channels_first": #Returns a string, either 'channels_first' or 'channels_last'
        inputShape = (depth, height, width)
        chanDim = 1
    
    # The axis that should be normalized, after a Conv2D layer with data_format="channels_first", 
    # set axis=1 in BatchNormalization.

    model.add(Conv2D(32, (3,3), padding="same", input_shape=inputShape))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(3,3)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, (3,3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

    model.add(Conv2D(64, (3,3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(128, (3,3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

    model.add(Conv2D(128, (3,3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(1024))
    model.add(Activation("relu"))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))

    model.add(Dense(classes))
    model.add(Activation("sigmoid"))

    return model

# %%
# Build model
gender_model = build_model(width=img_dims[0], height=img_dims[1], depth=img_dims[2], classes=2)

# %%
# Compile the model
gender_model.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy"])

# %%
# Model summary
gender_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 96, 96, 32)        896
#
#  activation (Activation)     (None, 96, 96, 32)        0
#
#  batch_normalization (Batch  (None, 96, 96, 32)        128
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 32, 32, 32)        0
#  D)
#
#  dropout (Dropout)           (None, 32, 32, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 64)        18496
#
#  activation_1 (Activation)   (None, 32, 32, 64)        0
#
#  batch_normalization_1 (Bat  (None, 32, 32, 64)        256
#  chNormalization)
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 64)        36928
#
#  activation_2 (Activation)   (None, 32, 32, 64)        0
#
#  batch_normalization_2 (Bat  (None, 32, 32, 64)        256
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 16, 16, 64)        0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 16, 16, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 128)       73856
#
#  activation_3 (Activation)   (None, 16, 16, 128)       0
#
#  batch_normalization_3 (Bat  (None, 16, 16, 128)       512
#  chNormalization)
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 128)       147584
#
#  activation_4 (Activation)   (None, 16, 16, 128)       0
#
#  batch_normalization_4 (Bat  (None, 16, 16, 128)       512
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 8, 8, 128)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 8, 8, 128)         0
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 1024)              8389632
#
#  activation_5 (Activation)   (None, 1024)              0
#
#  batch_normalization_5 (Bat  (None, 1024)              4096
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 2)                 2050
#
#  activation_6 (Activation)   (None, 2)                 0
#
# =================================================================
# Total params: 8675202 (33.09 MB)
# Trainable params: 8672322 (33.08 MB)
# Non-trainable params: 2880 (11.25 KB)
# _________________________________________________________________

# %%
# Train the model
gender_model_info = gender_model.fit(aug.flow(X_train, y_train, batch_size=batch_size),
                        validation_data=(X_test,y_test),
                        steps_per_epoch=len(X_test) // batch_size,
                        epochs=epochs, verbose=1,
                        )
# Out:
# Epoch 1/100
# 7/7 [==============================] - 3s 436ms/step - loss: 0.9571 - accuracy: 0.6406 - val_loss: 0.6838 - val_accuracy: 0.5390
# Epoch 2/100
# 7/7 [==============================] - 3s 429ms/step - loss: 0.6717 - accuracy: 0.7522 - val_loss: 0.7010 - val_accuracy: 0.5390
# Epoch 3/100
# 7/7 [==============================] - 3s 415ms/step - loss: 0.6499 - accuracy: 0.7790 - val_loss: 0.7961 - val_accuracy: 0.5390
# Epoch 4/100
# 7/7 [==============================] - 3s 418ms/step - loss: 0.5267 - accuracy: 0.8170 - val_loss: 0.8971 - val_accuracy: 0.5390
# Epoch 5/100
# 7/7 [==============================] - 3s 404ms/step - loss: 0.4968 - accuracy: 0.8170 - val_loss: 1.0143 - val_accuracy: 0.5390
# Epoch 6/100
# 7/7 [==============================] - 3s 400ms/step - loss: 0.4201 - accuracy: 0.8307 - val_loss: 1.3005 - val_accuracy: 0.5390
# Epoch 7/100
# 7/7 [==============================] - 3s 435ms/step - loss: 0.4366 - accuracy: 0.8259 - val_loss: 0.7917 - val_accuracy: 0.5390
# Epoch 8/100
# 7/7 [==============================] - 3s 462ms/step - loss: 0.4085 - accuracy: 0.8438 - val_loss: 1.1390 - val_accuracy: 0.5390
# Epoch 9/100
# 7/7 [==============================] - 3s 432ms/step - loss: 0.3597 - accuracy: 0.8490 - val_loss: 1.3912 - val_accuracy: 0.5390
# Epoch 10/100
# 7/7 [==============================] - 3s 430ms/step - loss: 0.4295 - accuracy: 0.8215 - val_loss: 1.4939 - val_accuracy: 0.5390
# Epoch 11/100
# 7/7 [==============================] - 3s 513ms/step - loss: 0.3456 - accuracy: 0.8616 - val_loss: 1.8044 - val_accuracy: 0.5390
# Epoch 12/100
# 7/7 [==============================] - 3s 467ms/step - loss: 0.3157 - accuracy: 0.8741 - val_loss: 1.4888 - val_accuracy: 0.5390
# Epoch 13/100
# 7/7 [==============================] - 3s 489ms/step - loss: 0.3645 - accuracy: 0.8719 - val_loss: 2.3667 - val_accuracy: 0.5390
# Epoch 14/100
# 7/7 [==============================] - 3s 481ms/step - loss: 0.3923 - accuracy: 0.8705 - val_loss: 2.5776 - val_accuracy: 0.5390
# Epoch 15/100
# 7/7 [==============================] - 3s 466ms/step - loss: 0.3304 - accuracy: 0.8719 - val_loss: 2.5202 - val_accuracy: 0.5390
# Epoch 16/100
# 7/7 [==============================] - 3s 459ms/step - loss: 0.2798 - accuracy: 0.9085 - val_loss: 3.2836 - val_accuracy: 0.5390
# Epoch 17/100
# 7/7 [==============================] - 3s 458ms/step - loss: 0.3544 - accuracy: 0.8616 - val_loss: 2.9503 - val_accuracy: 0.5390
# Epoch 18/100
# 7/7 [==============================] - 3s 464ms/step - loss: 0.3249 - accuracy: 0.8817 - val_loss: 1.7841 - val_accuracy: 0.5390
# Epoch 19/100
# 7/7 [==============================] - 3s 473ms/step - loss: 0.3109 - accuracy: 0.8728 - val_loss: 1.9352 - val_accuracy: 0.5390
# Epoch 20/100
# 7/7 [==============================] - 3s 477ms/step - loss: 0.2806 - accuracy: 0.8996 - val_loss: 2.4133 - val_accuracy: 0.5390
# Epoch 21/100
# 7/7 [==============================] - 3s 471ms/step - loss: 0.2655 - accuracy: 0.8884 - val_loss: 1.9141 - val_accuracy: 0.5390
# Epoch 22/100
# 7/7 [==============================] - 3s 479ms/step - loss: 0.2811 - accuracy: 0.8973 - val_loss: 2.7281 - val_accuracy: 0.5390
# Epoch 23/100
# 7/7 [==============================] - 3s 481ms/step - loss: 0.2432 - accuracy: 0.9062 - val_loss: 2.4785 - val_accuracy: 0.5390
# Epoch 24/100
# 7/7 [==============================] - 3s 486ms/step - loss: 0.2786 - accuracy: 0.8996 - val_loss: 1.7473 - val_accuracy: 0.5390
# Epoch 25/100
# 7/7 [==============================] - 3s 489ms/step - loss: 0.2325 - accuracy: 0.9219 - val_loss: 1.0628 - val_accuracy: 0.5411
# Epoch 26/100
# 7/7 [==============================] - 3s 480ms/step - loss: 0.2891 - accuracy: 0.8970 - val_loss: 1.2316 - val_accuracy: 0.5411
# Epoch 27/100
# 7/7 [==============================] - 3s 483ms/step - loss: 0.2928 - accuracy: 0.8973 - val_loss: 0.8092 - val_accuracy: 0.5541
# Epoch 28/100
# 7/7 [==============================] - 3s 487ms/step - loss: 0.2568 - accuracy: 0.9040 - val_loss: 1.0232 - val_accuracy: 0.5541
# Epoch 29/100
# 7/7 [==============================] - 3s 492ms/step - loss: 0.2420 - accuracy: 0.9129 - val_loss: 1.1844 - val_accuracy: 0.5455
# Epoch 30/100
# 7/7 [==============================] - 3s 492ms/step - loss: 0.1796 - accuracy: 0.9308 - val_loss: 2.3978 - val_accuracy: 0.5390
# Epoch 31/100
# 7/7 [==============================] - 3s 502ms/step - loss: 0.2956 - accuracy: 0.8795 - val_loss: 1.4938 - val_accuracy: 0.5411
# Epoch 32/100
# 7/7 [==============================] - 3s 498ms/step - loss: 0.2476 - accuracy: 0.8973 - val_loss: 1.1738 - val_accuracy: 0.5541
# Epoch 33/100
# 7/7 [==============================] - 3s 499ms/step - loss: 0.2233 - accuracy: 0.9174 - val_loss: 0.5834 - val_accuracy: 0.7143
# Epoch 34/100
# 7/7 [==============================] - 3s 498ms/step - loss: 0.2338 - accuracy: 0.9085 - val_loss: 0.4664 - val_accuracy: 0.7944
# Epoch 35/100
# 7/7 [==============================] - 3s 499ms/step - loss: 0.2438 - accuracy: 0.9018 - val_loss: 0.6276 - val_accuracy: 0.6688
# Epoch 36/100
# 7/7 [==============================] - 3s 501ms/step - loss: 0.2054 - accuracy: 0.9199 - val_loss: 1.1111 - val_accuracy: 0.5996
# Epoch 37/100
# 7/7 [==============================] - 3s 503ms/step - loss: 0.2098 - accuracy: 0.9308 - val_loss: 1.1480 - val_accuracy: 0.5714
# Epoch 38/100
# 7/7 [==============================] - 3s 505ms/step - loss: 0.1862 - accuracy: 0.9219 - val_loss: 0.6488 - val_accuracy: 0.6602
# Epoch 39/100
# 7/7 [==============================] - 4s 513ms/step - loss: 0.2124 - accuracy: 0.9241 - val_loss: 0.5981 - val_accuracy: 0.6948
# Epoch 40/100
# 7/7 [==============================] - 3s 504ms/step - loss: 0.2537 - accuracy: 0.9039 - val_loss: 0.8606 - val_accuracy: 0.5909
# Epoch 41/100
# 7/7 [==============================] - 3s 506ms/step - loss: 0.2573 - accuracy: 0.8906 - val_loss: 0.6487 - val_accuracy: 0.7121
# Epoch 42/100
# 7/7 [==============================] - 4s 521ms/step - loss: 0.2075 - accuracy: 0.9219 - val_loss: 0.3731 - val_accuracy: 0.8420
# Epoch 43/100
# 7/7 [==============================] - 4s 515ms/step - loss: 0.2314 - accuracy: 0.8996 - val_loss: 0.4619 - val_accuracy: 0.7662
# Epoch 44/100
# 7/7 [==============================] - 4s 520ms/step - loss: 0.2025 - accuracy: 0.9286 - val_loss: 0.8934 - val_accuracy: 0.6190
# Epoch 45/100
# 7/7 [==============================] - 4s 523ms/step - loss: 0.2010 - accuracy: 0.9107 - val_loss: 0.9275 - val_accuracy: 0.6342
# Epoch 46/100
# 7/7 [==============================] - 4s 525ms/step - loss: 0.1719 - accuracy: 0.9291 - val_loss: 0.5049 - val_accuracy: 0.8052
# Epoch 47/100
# 7/7 [==============================] - 4s 526ms/step - loss: 0.1663 - accuracy: 0.9353 - val_loss: 0.5897 - val_accuracy: 0.7511
# Epoch 48/100
# 7/7 [==============================] - 4s 522ms/step - loss: 0.1377 - accuracy: 0.9509 - val_loss: 0.3833 - val_accuracy: 0.8225
# Epoch 49/100
# 7/7 [==============================] - 4s 526ms/step - loss: 0.1765 - accuracy: 0.9375 - val_loss: 0.3776 - val_accuracy: 0.8420
# Epoch 50/100
# 7/7 [==============================] - 4s 522ms/step - loss: 0.1743 - accuracy: 0.9353 - val_loss: 0.3144 - val_accuracy: 0.8745
# Epoch 51/100
# 7/7 [==============================] - 4s 524ms/step - loss: 0.1725 - accuracy: 0.9375 - val_loss: 0.3621 - val_accuracy: 0.8485
# Epoch 52/100
# 7/7 [==============================] - 4s 521ms/step - loss: 0.1477 - accuracy: 0.9509 - val_loss: 0.2698 - val_accuracy: 0.8853
# Epoch 53/100
# 7/7 [==============================] - 4s 528ms/step - loss: 0.1709 - accuracy: 0.9330 - val_loss: 0.3267 - val_accuracy: 0.8745
# Epoch 54/100
# 7/7 [==============================] - 4s 537ms/step - loss: 0.1682 - accuracy: 0.9353 - val_loss: 0.7903 - val_accuracy: 0.6775
# Epoch 55/100
# 7/7 [==============================] - 4s 521ms/step - loss: 0.1849 - accuracy: 0.9199 - val_loss: 0.2892 - val_accuracy: 0.8810
# Epoch 56/100
# 7/7 [==============================] - 4s 531ms/step - loss: 0.1395 - accuracy: 0.9442 - val_loss: 0.2886 - val_accuracy: 0.8766
# Epoch 57/100
# 7/7 [==============================] - 4s 531ms/step - loss: 0.1324 - accuracy: 0.9554 - val_loss: 0.3774 - val_accuracy: 0.8333
# Epoch 58/100
# 7/7 [==============================] - 4s 540ms/step - loss: 0.1245 - accuracy: 0.9509 - val_loss: 0.2296 - val_accuracy: 0.9069
# Epoch 59/100
# 7/7 [==============================] - 4s 533ms/step - loss: 0.1831 - accuracy: 0.9382 - val_loss: 0.2802 - val_accuracy: 0.8961
# Epoch 60/100
# 7/7 [==============================] - 4s 533ms/step - loss: 0.0767 - accuracy: 0.9732 - val_loss: 0.2295 - val_accuracy: 0.9156
# Epoch 61/100
# 7/7 [==============================] - 4s 536ms/step - loss: 0.1623 - accuracy: 0.9382 - val_loss: 0.4425 - val_accuracy: 0.8680
# Epoch 62/100
# 7/7 [==============================] - 4s 520ms/step - loss: 0.1737 - accuracy: 0.9359 - val_loss: 0.4069 - val_accuracy: 0.8745
# Epoch 63/100
# 7/7 [==============================] - 4s 536ms/step - loss: 0.1533 - accuracy: 0.9442 - val_loss: 0.3989 - val_accuracy: 0.8571
# Epoch 64/100
# 7/7 [==============================] - 4s 525ms/step - loss: 0.1486 - accuracy: 0.9359 - val_loss: 0.4642 - val_accuracy: 0.9199
# Epoch 65/100
# 7/7 [==============================] - 4s 538ms/step - loss: 0.1200 - accuracy: 0.9554 - val_loss: 0.2838 - val_accuracy: 0.9199
# Epoch 66/100
# 7/7 [==============================] - 4s 541ms/step - loss: 0.0860 - accuracy: 0.9680 - val_loss: 0.2505 - val_accuracy: 0.9307
# Epoch 67/100
# 7/7 [==============================] - 4s 533ms/step - loss: 0.1516 - accuracy: 0.9405 - val_loss: 0.2318 - val_accuracy: 0.9286
# Epoch 68/100
# 7/7 [==============================] - 4s 543ms/step - loss: 0.1268 - accuracy: 0.9554 - val_loss: 0.2687 - val_accuracy: 0.9113
# Epoch 69/100
# 7/7 [==============================] - 4s 540ms/step - loss: 0.1890 - accuracy: 0.9196 - val_loss: 0.8947 - val_accuracy: 0.8203
# Epoch 70/100
# 7/7 [==============================] - 4s 569ms/step - loss: 0.1320 - accuracy: 0.9487 - val_loss: 0.3661 - val_accuracy: 0.9069
# Epoch 71/100
# 7/7 [==============================] - 4s 541ms/step - loss: 0.1482 - accuracy: 0.9531 - val_loss: 0.9037 - val_accuracy: 0.8052
# Epoch 72/100
# 7/7 [==============================] - 4s 516ms/step - loss: 0.1332 - accuracy: 0.9554 - val_loss: 0.8164 - val_accuracy: 0.8095
# Epoch 73/100
# 7/7 [==============================] - 4s 540ms/step - loss: 0.1154 - accuracy: 0.9621 - val_loss: 0.2045 - val_accuracy: 0.9372
# Epoch 74/100
# 7/7 [==============================] - 4s 546ms/step - loss: 0.1167 - accuracy: 0.9442 - val_loss: 0.1938 - val_accuracy: 0.9372
# Epoch 75/100
# 7/7 [==============================] - 4s 538ms/step - loss: 0.1135 - accuracy: 0.9643 - val_loss: 0.2325 - val_accuracy: 0.9307
# Epoch 76/100
# 7/7 [==============================] - 4s 535ms/step - loss: 0.1026 - accuracy: 0.9621 - val_loss: 0.2092 - val_accuracy: 0.9307
# Epoch 77/100
# 7/7 [==============================] - 4s 546ms/step - loss: 0.1128 - accuracy: 0.9554 - val_loss: 0.1753 - val_accuracy: 0.9351
# Epoch 78/100
# 7/7 [==============================] - 4s 536ms/step - loss: 0.0744 - accuracy: 0.9817 - val_loss: 0.1560 - val_accuracy: 0.9459
# Epoch 79/100
# 7/7 [==============================] - 4s 534ms/step - loss: 0.1085 - accuracy: 0.9554 - val_loss: 0.1786 - val_accuracy: 0.9481
# Epoch 80/100
# 7/7 [==============================] - 4s 519ms/step - loss: 0.1192 - accuracy: 0.9611 - val_loss: 0.1297 - val_accuracy: 0.9632
# Epoch 81/100
# 7/7 [==============================] - 4s 523ms/step - loss: 0.1242 - accuracy: 0.9576 - val_loss: 0.1965 - val_accuracy: 0.9307
# Epoch 82/100
# 7/7 [==============================] - 4s 533ms/step - loss: 0.1065 - accuracy: 0.9509 - val_loss: 0.1675 - val_accuracy: 0.9416
# Epoch 83/100
# 7/7 [==============================] - 4s 529ms/step - loss: 0.0737 - accuracy: 0.9710 - val_loss: 0.3096 - val_accuracy: 0.8961
# Epoch 84/100
# 7/7 [==============================] - 4s 545ms/step - loss: 0.1422 - accuracy: 0.9375 - val_loss: 0.3231 - val_accuracy: 0.9091
# Epoch 85/100
# 7/7 [==============================] - 4s 539ms/step - loss: 0.1299 - accuracy: 0.9487 - val_loss: 0.1700 - val_accuracy: 0.9394
# Epoch 86/100
# 7/7 [==============================] - 4s 530ms/step - loss: 0.0961 - accuracy: 0.9643 - val_loss: 0.1508 - val_accuracy: 0.9459
# Epoch 87/100
# 7/7 [==============================] - 4s 547ms/step - loss: 0.1238 - accuracy: 0.9487 - val_loss: 0.1516 - val_accuracy: 0.9481
# Epoch 88/100
# 7/7 [==============================] - 4s 548ms/step - loss: 0.1175 - accuracy: 0.9554 - val_loss: 0.2023 - val_accuracy: 0.9394
# Epoch 89/100
# 7/7 [==============================] - 4s 547ms/step - loss: 0.1527 - accuracy: 0.9375 - val_loss: 0.7357 - val_accuracy: 0.7879
# Epoch 90/100
# 7/7 [==============================] - 4s 534ms/step - loss: 0.1120 - accuracy: 0.9554 - val_loss: 0.7104 - val_accuracy: 0.8571
# Epoch 91/100
# 7/7 [==============================] - 4s 537ms/step - loss: 0.0862 - accuracy: 0.9754 - val_loss: 0.5014 - val_accuracy: 0.8701
# Epoch 92/100
# 7/7 [==============================] - 4s 545ms/step - loss: 0.1167 - accuracy: 0.9576 - val_loss: 0.3393 - val_accuracy: 0.8874
# Epoch 93/100
# 7/7 [==============================] - 4s 528ms/step - loss: 0.1100 - accuracy: 0.9565 - val_loss: 0.4671 - val_accuracy: 0.8506
# Epoch 94/100
# 7/7 [==============================] - 4s 521ms/step - loss: 0.0893 - accuracy: 0.9611 - val_loss: 0.2353 - val_accuracy: 0.9091
# Epoch 95/100
# 7/7 [==============================] - 4s 538ms/step - loss: 0.1077 - accuracy: 0.9509 - val_loss: 0.1195 - val_accuracy: 0.9545
# Epoch 96/100
# 7/7 [==============================] - 4s 534ms/step - loss: 0.1108 - accuracy: 0.9509 - val_loss: 0.1277 - val_accuracy: 0.9567
# Epoch 97/100
# 7/7 [==============================] - 4s 542ms/step - loss: 0.0961 - accuracy: 0.9754 - val_loss: 0.1936 - val_accuracy: 0.9437
# Epoch 98/100
# 7/7 [==============================] - 4s 542ms/step - loss: 0.1690 - accuracy: 0.9487 - val_loss: 0.1712 - val_accuracy: 0.9502
# Epoch 99/100
# 7/7 [==============================] - 4s 557ms/step - loss: 0.0721 - accuracy: 0.9754 - val_loss: 0.1341 - val_accuracy: 0.9545
# Epoch 100/100
# 7/7 [==============================] - 4s 550ms/step - loss: 0.1139 - accuracy: 0.9576 - val_loss: 0.4734 - val_accuracy: 0.8442

# %%
# Save the model in .h5 file
gender_model.save('/Users/ronja/Desktop/DS22_EC/8_Deep_Learning/Kunskapskontoller_DL/Kunskapskontroll_2/models/gender_model_100e.h5')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import matplotlib.pyplot as plt

# Plot accuracy score
plt.figure(figsize=(20, 10))

plt.subplot(1, 2, 1)
plt.ylabel('Loss', fontsize=16)
plt.plot(gender_model_info.history['loss'], label='Training Loss')
plt.plot(gender_model_info.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')

plt.subplot(1, 2, 2)
plt.ylabel('Accuracy', fontsize=16)
plt.plot(gender_model_info.history['accuracy'], label='Training Accuracy')
plt.plot(gender_model_info.history['val_accuracy'], label='Validation Accuracy')
plt.legend(loc='lower right')

plt.show()
